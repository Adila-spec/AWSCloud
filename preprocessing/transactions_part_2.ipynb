# %% [markdown]
# # Preprocessing transactions.csv Part 2

# %%
import numpy as np
import pandas as pd
import boto3
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime

pd.options.display.float_format = '{:.4f}'.format

# %% [markdown]
# ### Loading Data via S3

# %%
bucket='ads-508-group-6-raw'
data_key = 'transactions.csv'

s3 = boto3.client('s3')
transactions_obj = s3.get_object(Bucket = bucket, Key = data_key)

transactions_df = pd.read_csv(transactions_obj['Body'])

# %% [markdown]
# ### Loading Data Locally

# %%
transactions_df = pd.read_csv("C:\\Users\\garyb\\OneDrive\\Documents\\GitHub\\recommendation-engine\\data\\historical_transactions.csv")

# %%
transactions_df.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#    price  sales_channel_id
# 0 0.0508                 2
# 1 0.0305                 2
# 2 0.0152                 2
# 3 0.0169                 2
# 4 0.0169                 2

# %% [markdown]
# ### Recasting Data Types

# %%
transactions_df['t_dat'] = pd.to_datetime(transactions_df['t_dat'], format='%Y-%m-%d')

# %%
transactions_df = transactions_df.astype({'article_id':'str',
                                          'sales_channel_id':'str'})

# %% [markdown]
# ### Data Mining Historical Transaction Data

# %%
def max_min(x):
    return x.max() - x.min()

# %%
df=transactions_df.groupby('customer_id').agg({'t_dat':max_min, 
                                               'article_id':'count', 
                                               'price':'sum', 
                                               'sales_channel_id':lambda val: (val == '1').count()})

# %%
df['t_dat'] = pd.to_numeric(df['t_dat'].dt.days, downcast='integer')

# %%
df.rename(columns={"t_dat": "days_min_max", 
                   "article_id": "total_articles_purchased",
                   'price':"total_amount_spent",
                   "sales_channel_id":"sales_channel_1_count"})
# Out:
#                                                     days_min_max  \
# customer_id
# 00000dbacae5abe5e23885899a1fa44253a17956c6d1c3d...           450
# 0000423b00ade91418cceaf3b26c6af3dd342b51fd051ee...           527
# 000058a12d5b43e67d225668fa1f8d618c13dc232df0cad...           501
# 00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2c...             0
# 00006413d8573cd20ed7128e53b7b13819fe5cfc2d801fe...           362
# ...                                                          ...
# ffffaff3905b803d1c7e153a1378a5151e1f34f236ba545...             0
# ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e4747...           350
# ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab53...           519
# ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a17...           489
# ffffd9ac14e89946416d80e791d064701994755c3ab686a...             0
#
#                                                     total_articles_purchased  \
# customer_id
# 00000dbacae5abe5e23885899a1fa44253a17956c6d1c3d...                        20
# 0000423b00ade91418cceaf3b26c6af3dd342b51fd051ee...                        71
# 000058a12d5b43e67d225668fa1f8d618c13dc232df0cad...                         7
# 00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2c...                         2
# 00006413d8573cd20ed7128e53b7b13819fe5cfc2d801fe...                         6
# ...                                                                      ...
# ffffaff3905b803d1c7e153a1378a5151e1f34f236ba545...                         1
# ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e4747...                        28
# ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab53...                        58
# ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a17...                        35
# ffffd9ac14e89946416d80e791d064701994755c3ab686a...                         1
#
#                                                     total_amount_spent  \
# customer_id
# 00000dbacae5abe5e23885899a1fa44253a17956c6d1c3d...              0.5982
# 0000423b00ade91418cceaf3b26c6af3dd342b51fd051ee...              2.2378
# 000058a12d5b43e67d225668fa1f8d618c13dc232df0cad...              0.2151
# 00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2c...              0.0610
# 00006413d8573cd20ed7128e53b7b13819fe5cfc2d801fe...              0.2139
# ...                                                                ...
# ffffaff3905b803d1c7e153a1378a5151e1f34f236ba545...              0.1220
# ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e4747...              0.7521
# ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab53...              1.2996
# ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a17...              0.6467
# ffffd9ac14e89946416d80e791d064701994755c3ab686a...              0.0847
#
#                                                     sales_channel_1_count
# customer_id
# 00000dbacae5abe5e23885899a1fa44253a17956c6d1c3d...                     20
# 0000423b00ade91418cceaf3b26c6af3dd342b51fd051ee...                     71
# 000058a12d5b43e67d225668fa1f8d618c13dc232df0cad...                      7
# 00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2c...                      2
# 00006413d8573cd20ed7128e53b7b13819fe5cfc2d801fe...                      6
# ...                                                                   ...
# ffffaff3905b803d1c7e153a1378a5151e1f34f236ba545...                      1
# ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e4747...                     28
# ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab53...                     58
# ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a17...                     35
# ffffd9ac14e89946416d80e791d064701994755c3ab686a...                      1
#
# [1195314 rows x 4 columns]

# %%
df.reset_index().to_csv("C:\\Users\\garyb\\OneDrive\\Documents\\GitHub\\recommendation-engine\\data\\historical_transaction_agg.csv", 
                    index = False)

# %% [markdown]
# ### Data Mining Current Period Data

# %%
population_df = pd.read_csv("C:\\Users\\garyb\\OneDrive\\Documents\\GitHub\\recommendation-engine\\data\\transactions_population.csv")

# %%
population_df.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2020-01-01  0034b3dced3e565a43438bdfb5447e7321fea65388b398...   835247001
# 1  2020-01-01  00410b91d62eefa76958fa5cac12f5daa7cfc0556e417d...   802930002
# 2  2020-01-01  00410b91d62eefa76958fa5cac12f5daa7cfc0556e417d...   760084008
# 3  2020-01-01  004b0fb384bcab2f8e1059dd5ca68c17580365ab95c05a...   804662002
# 4  2020-01-01  004b0fb384bcab2f8e1059dd5ca68c17580365ab95c05a...   801554002
#
#    price  sales_channel_id
# 0 0.0339                 2
# 1 0.0678                 2
# 2 0.0254                 2
# 3 0.0339                 2
# 4 0.0169                 2

# %%
population_df['t_dat'] = pd.to_datetime(population_df['t_dat'], format='%Y-%m-%d')

# %%
population_df = population_df.astype({'article_id':'str',
                                      'sales_channel_id':'str'})

# %%
df=population_df.groupby('customer_id').agg({'t_dat':max_min, 
                                             'article_id':'count', 
                                             'price':'sum', 
                                             'sales_channel_id':lambda val: (val == '1').count()})

# %%
df['t_dat'] = pd.to_numeric(df['t_dat'].dt.days, downcast='integer')

# %%
df.rename(columns={"t_dat": "days_min_max", 
                   "article_id": "total_articles_purchased",
                   'price':"total_amount_spent",
                   "sales_channel_id":"sales_channel_1_count"})
# Out:
#                                                     days_min_max  \
# customer_id
# 00000dbacae5abe5e23885899a1fa44253a17956c6d1c3d...             0
# 0000423b00ade91418cceaf3b26c6af3dd342b51fd051ee...            40
# 000058a12d5b43e67d225668fa1f8d618c13dc232df0cad...             0
# 00007e8d4e54114b5b2a9b51586325a8d0fa74ea23ef773...             0
# 00009d946eec3ea54add5ba56d5210ea898def4b46c6857...            71
# ...                                                          ...
# ffff4c4e8b57b633c1ddf8fbd53db16b962cf831baf9ed6...             0
# ffff61677073258d461e043cc9ed4ed97be5617a920640f...            21
# ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e4747...             0
# ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab53...            41
# ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a17...             0
#
#                                                     total_articles_purchased  \
# customer_id
# 00000dbacae5abe5e23885899a1fa44253a17956c6d1c3d...                         5
# 0000423b00ade91418cceaf3b26c6af3dd342b51fd051ee...                        19
# 000058a12d5b43e67d225668fa1f8d618c13dc232df0cad...                         3
# 00007e8d4e54114b5b2a9b51586325a8d0fa74ea23ef773...                         2
# 00009d946eec3ea54add5ba56d5210ea898def4b46c6857...                        21
# ...                                                                      ...
# ffff4c4e8b57b633c1ddf8fbd53db16b962cf831baf9ed6...                         3
# ffff61677073258d461e043cc9ed4ed97be5617a920640f...                         8
# ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e4747...                         2
# ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab53...                        18
# ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a17...                         1
#
#                                                     total_amount_spent  \
# customer_id
# 00000dbacae5abe5e23885899a1fa44253a17956c6d1c3d...              0.0936
# 0000423b00ade91418cceaf3b26c6af3dd342b51fd051ee...              0.4726
# 000058a12d5b43e67d225668fa1f8d618c13dc232df0cad...              0.0694
# 00007e8d4e54114b5b2a9b51586325a8d0fa74ea23ef773...              0.0534
# 00009d946eec3ea54add5ba56d5210ea898def4b46c6857...              0.6582
# ...                                                                ...
# ffff4c4e8b57b633c1ddf8fbd53db16b962cf831baf9ed6...              0.0677
# ffff61677073258d461e043cc9ed4ed97be5617a920640f...              0.1751
# ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e4747...              0.0712
# ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab53...              0.4566
# ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a17...              0.0339
#
#                                                     sales_channel_1_count
# customer_id
# 00000dbacae5abe5e23885899a1fa44253a17956c6d1c3d...                      5
# 0000423b00ade91418cceaf3b26c6af3dd342b51fd051ee...                     19
# 000058a12d5b43e67d225668fa1f8d618c13dc232df0cad...                      3
# 00007e8d4e54114b5b2a9b51586325a8d0fa74ea23ef773...                      2
# 00009d946eec3ea54add5ba56d5210ea898def4b46c6857...                     21
# ...                                                                   ...
# ffff4c4e8b57b633c1ddf8fbd53db16b962cf831baf9ed6...                      3
# ffff61677073258d461e043cc9ed4ed97be5617a920640f...                      8
# ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e4747...                      2
# ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab53...                     18
# ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a17...                      1
#
# [469376 rows x 4 columns]

# %%
df.reset_index().to_csv("C:\\Users\\garyb\\OneDrive\\Documents\\GitHub\\recommendation-engine\\data\\population_transaction_agg.csv", 
                    index = False)

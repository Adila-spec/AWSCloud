# %% [markdown]
# # Preprocessing customers.csv Part 2

# %%
import numpy as np
import pandas as pd
import boto3
import matplotlib.pyplot as plt
import seaborn as sns
import os

pd.options.display.float_format = '{:.4f}'.format

# %% [markdown]
# ### Loading Data via S3

# %%
bucket='ads-508-group-6-raw'
data_key = 'customers_processed_part_1'

s3 = boto3.client('s3')
customers_obj = s3.get_object(Bucket = bucket, Key = data_key)

customers_df = pd.read_csv(customers_obj['Body'])

# %% [markdown]
# ### Loading Data Locally

# %%
customers_df = pd.read_csv("C:\\Users\\garyb\\OneDrive\\Documents\\GitHub\\recommendation-engine\\data\\customers_processed_part_1.csv")

# %%
customers_df.head()
# Out:
#                                          customer_id     FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3... 0.0000  0.0000
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e... 0.0000  0.0000
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca... 0.0000  0.0000
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2... 0.0000  0.0000
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f... 1.0000  1.0000
#
#   club_member_status fashion_news_frequency     age  \
# 0             ACTIVE                   NONE 49.0000
# 1             ACTIVE                   NONE 25.0000
# 2             ACTIVE                   NONE 24.0000
# 3             ACTIVE                   NONE 54.0000
# 4             ACTIVE              Regularly 52.0000
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# 3  5d36574f52495e81f019b680c843c443bd343d5ca5b1c2...
# 4  25fa5ddee9aac01b35208d01736e57942317d756b32ddd...

# %%
customers_df.describe()
# Out:
#                 FN       Active          age
# count 1371980.0000 1371980.0000 1371980.0000
# mean        0.3476       0.3385      36.3362
# std         0.4762       0.4732      14.2384
# min         0.0000       0.0000      16.0000
# 25%         0.0000       0.0000      24.0000
# 50%         0.0000       0.0000      32.0000
# 75%         1.0000       1.0000      49.0000
# max         1.0000       1.0000      99.0000

# %% [markdown]
# ### Loading Data via S3

# %%
bucket='ads-508-group-6-raw'
data_key = 'transaction_population'

s3 = boto3.client('s3')
customer_population_obj = s3.get_object(Bucket = bucket, Key = data_key)

customer_population_df = pd.read_csv(customer_population_obj['Body'])

# %% [markdown]
# ### Loading Data Locally

# %%
transaction_population_df = pd.read_csv("C:\\Users\\garyb\\OneDrive\\Documents\\GitHub\\recommendation-engine\\data\\transactions_population.csv")

# %%
transaction_population_df.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2020-01-01  0034b3dced3e565a43438bdfb5447e7321fea65388b398...   835247001
# 1  2020-01-01  00410b91d62eefa76958fa5cac12f5daa7cfc0556e417d...   802930002
# 2  2020-01-01  00410b91d62eefa76958fa5cac12f5daa7cfc0556e417d...   760084008
# 3  2020-01-01  004b0fb384bcab2f8e1059dd5ca68c17580365ab95c05a...   804662002
# 4  2020-01-01  004b0fb384bcab2f8e1059dd5ca68c17580365ab95c05a...   801554002
#
#    price  sales_channel_id
# 0 0.0339                 2
# 1 0.0678                 2
# 2 0.0254                 2
# 3 0.0339                 2
# 4 0.0169                 2

# %%
transaction_population_df.nunique()
# Out:
# t_dat                   91
# customer_id         469376
# article_id           41649
# price                 6829
# sales_channel_id         2
# dtype: int64

# %% [markdown]
# ### Loading Data via S3

# %%
bucket='ads-508-group-6-raw'
data_key = 'target_labels'

s3 = boto3.client('s3')
labels_obj = s3.get_object(Bucket = bucket, Key = data_key)

labels_df = pd.read_csv(labels_obj['Body'])

# %% [markdown]
# ### Loading Data Locally

# %%
labels_df = pd.read_csv("C:\\Users\\garyb\\OneDrive\\Documents\\GitHub\\recommendation-engine\\data\\target_labels.csv")

# %%
labels_df.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2020-04-01  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   727808001
# 1  2020-04-01  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   727808007
# 2  2020-04-01  000563485cbb7850b0a93c6606f89c5b961c6647d1bd48...   567532015
# 3  2020-04-01  000563485cbb7850b0a93c6606f89c5b961c6647d1bd48...   706104009
# 4  2020-04-01  00083cda041544b2fbb0e0d2905ad17da7cf1007526fb4...   783504004
#
#    price  sales_channel_id
# 0 0.0678                 2
# 1 0.0678                 2
# 2 0.0424                 2
# 3 0.0424                 2
# 4 0.0191                 2

# %%
labels_df.describe()
# Out:
#           article_id        price  sales_channel_id
# count   4467204.0000 4467204.0000      4467204.0000
# mean  771633152.7204       0.0264            1.7802
# std   119970811.4629       0.0156            0.4141
# min   108775015.0000       0.0000            1.0000
# 25%   729603001.0000       0.0169            2.0000
# 50%   816083002.0000       0.0248            2.0000
# 75%   852775002.0000       0.0339            2.0000
# max   935356001.0000       0.5013            2.0000

# %%
labels_df.nunique()
# Out:
# t_dat                   91
# customer_id         538352
# article_id           39173
# price                 5806
# sales_channel_id         2
# dtype: int64

# %% [markdown]
# ### Reducing Full Customers Table to Experiment Population

# %%
customers_df = customers_df[customers_df.customer_id.isin(transaction_population_df.customer_id)]

# %%
customers_df.describe()
# Out:
#                FN      Active         age
# count 469376.0000 469376.0000 469376.0000
# mean       0.3971      0.3907     35.7225
# std        0.4893      0.4879     13.9363
# min        0.0000      0.0000     16.0000
# 25%        0.0000      0.0000     24.0000
# 50%        0.0000      0.0000     31.0000
# 75%        1.0000      1.0000     48.0000
# max        1.0000      1.0000     99.0000

# %% [markdown]
# ### Reducing Full Labels Table to Unique Users

# %%
labels_df = labels_df.drop_duplicates(subset = ['customer_id'])

# %%
labels_df.describe()
# Out:
#           article_id       price  sales_channel_id
# count    538352.0000 538352.0000       538352.0000
# mean  764796290.9093      0.0277            1.7860
# std   121927004.6399      0.0166            0.4102
# min   108775015.0000      0.0002            1.0000
# 25%   718634001.0000      0.0169            2.0000
# 50%   808698004.0000      0.0254            2.0000
# 75%   849361005.0000      0.0339            2.0000
# max   935356001.0000      0.3373            2.0000

# %% [markdown]
# ### Generating Target Labels

# %%
cutomers_merged = pd.merge(customers_df, 
                           labels_df, 
                           how='left', 
                           on=['customer_id'],)

# %%
cutomers_merged.head()
# Out:
#                                          customer_id     FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3... 0.0000  0.0000
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e... 0.0000  0.0000
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca... 0.0000  0.0000
# 3  00007e8d4e54114b5b2a9b51586325a8d0fa74ea23ef77... 0.0000  0.0000
# 4  00009d946eec3ea54add5ba56d5210ea898def4b46c685... 1.0000  1.0000
#
#   club_member_status fashion_news_frequency     age  \
# 0             ACTIVE                   NONE 49.0000
# 1             ACTIVE                   NONE 25.0000
# 2             ACTIVE                   NONE 24.0000
# 3             ACTIVE                   NONE 20.0000
# 4             ACTIVE              Regularly 56.0000
#
#                                          postal_code       t_dat  \
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...         NaN
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...  2020-04-22
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...  2020-04-01
# 3  2c29ae653a9282cce4151bd87643c907644e09541abc28...         NaN
# 4  b31984b20a8c478de38eaf113c581ff64e63c4242e607b...  2020-04-24
#
#       article_id  price  sales_channel_id
# 0            NaN    NaN               NaN
# 1 599580055.0000 0.0169            2.0000
# 2 727808001.0000 0.0678            2.0000
# 3            NaN    NaN               NaN
# 4 562245099.0000 0.0325            2.0000

# %%
cutomers_merged['churn'] = cutomers_merged['sales_channel_id'].replace([1, 2],
                                                                       [0, 0])
cutomers_merged['churn'] = cutomers_merged['churn'].fillna(1)

# %%
cutomers_merged.head()
# Out:
#                                          customer_id     FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3... 0.0000  0.0000
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e... 0.0000  0.0000
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca... 0.0000  0.0000
# 3  00007e8d4e54114b5b2a9b51586325a8d0fa74ea23ef77... 0.0000  0.0000
# 4  00009d946eec3ea54add5ba56d5210ea898def4b46c685... 1.0000  1.0000
#
#   club_member_status fashion_news_frequency     age  \
# 0             ACTIVE                   NONE 49.0000
# 1             ACTIVE                   NONE 25.0000
# 2             ACTIVE                   NONE 24.0000
# 3             ACTIVE                   NONE 20.0000
# 4             ACTIVE              Regularly 56.0000
#
#                                          postal_code       t_dat  \
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...         NaN
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...  2020-04-22
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...  2020-04-01
# 3  2c29ae653a9282cce4151bd87643c907644e09541abc28...         NaN
# 4  b31984b20a8c478de38eaf113c581ff64e63c4242e607b...  2020-04-24
#
#       article_id  price  sales_channel_id  churn
# 0            NaN    NaN               NaN 1.0000
# 1 599580055.0000 0.0169            2.0000 0.0000
# 2 727808001.0000 0.0678            2.0000 0.0000
# 3            NaN    NaN               NaN 1.0000
# 4 562245099.0000 0.0325            2.0000 0.0000

# %%
cutomers_merged = cutomers_merged.drop(columns=['t_dat', 
                                                'article_id', 
                                                'price', 
                                                'sales_channel_id'])

# %%
cutomers_merged.to_csv("C:\\Users\\garyb\\OneDrive\\Documents\\GitHub\\recommendation-engine\\data\\customers_processed_part_2.csv", 
                    index = False)
